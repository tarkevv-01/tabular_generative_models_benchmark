# %%
import os, sys
import pandas as pd

from tab_gmb.dataset import Dataset
from tab_gmb.models import CTGANModel
from tab_gmb.tuner import TPETuner
from tab_gmb.experiment_runer import ExperimentRunner

# %%
test_dir = './titanic.csv'
test_data = pd.read_csv(test_dir)

dataset = Dataset(
    data=test_data,
    name='titanic',
    task_type='classification',
    target_column='Survived',
    num_columns=["Age", "Fare", "SibSp", "Parch"],
    cat_columns=["Pclass", "Sex", "Embarked"],
    verbose_init=True
)
# Out:
# Предупреждение: Колонки не классифицированы как числовые или категориальные: {'Cabin', 'Name', 'PassengerId', 'Ticket'}
# Датасет 'titanic' успешно валидирован:
#   - Размер: (712, 12)
#   - Тип задачи: classification
#   - Целевая колонка: Survived
#   - Числовые колонки (4): ['Age', 'Fare', 'SibSp', 'Parch']
#   - Категориальные колонки (3): ['Pclass', 'Sex', 'Embarked']

# %%
ctgan_space = {
    'discriminator_lr': (4e-4, 2.1e-3, 5e-5),
    'generator_lr': (5e-5, 5e-3, 5e-5),
    'batch_size': [100, 500, 1000],
    'embedding_dim': [32, 128],
    'generator_dim': [[128, 128, 128], [128, 128, 128, 128]],
    'discriminator_dim': [[256, 256], [256, 256, 256]],
    'generator_decay': (1e-6, 6.4e-6, 1e-7),
    'discriminator_decay': (1e-6, 8e-6, 1e-6),
    'log_frequency': [False, True],
    'transformation_num_type': ['CDF', 'PLE_CDF'],
    'transformation_cat_type': ['OHE']
    
}

# %%
model= CTGANModel()

# %%
tuner = TPETuner(n_trials=50)


runner = ExperimentRunner(
    dataset=dataset,
    model=model,
    tuner=tuner,
    hyperparameter_space=ctgan_space,
    metrics=['c2st', 'ml_efficacy', 'pair', 'shape'],
    metric_weights={'c2st': 1.0, 'ml_efficacy': -1.0, 'pair': -1.0, 'shape': -1.0},
    n_folds=3
)


results = runner.run_experiment()
# Out:
# --------------------------------------------------
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00115, 'embedding_dim': 32, 'generator_decay': 6.4e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00055, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.3739183827092487
# {'c2st': 0.9061032863849765, 'ml_efficacy': 0.5691756606415376, 'pair': 0.86524093097866, 'shape': 0.8456050774740277}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0013000000000000002, 'embedding_dim': 32, 'generator_decay': 1.2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.5664069201518707
# {'c2st': 0.886443661971831, 'ml_efficacy': 0.6462156673981613, 'pair': 0.8698380018675702, 'shape': 0.9367969128579702}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00135, 'embedding_dim': 32, 'generator_decay': 3.3999999999999996e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0007, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# Score:
# -1.6084883976056985
# {'c2st': 0.8952138758476785, 'ml_efficacy': 0.7621307051678822, 'pair': 0.8632182016223741, 'shape': 0.8783533666631209}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 1000, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00165, 'embedding_dim': 128, 'generator_decay': 2.4e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0032500000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.432180444550565
# {'c2st': 0.9547470005216484, 'ml_efficacy': 0.6503003437786047, 'pair': 0.8663969839302078, 'shape': 0.870230117363401}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 1000, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0017000000000000001, 'embedding_dim': 128, 'generator_decay': 4.7e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0036000000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# Score:
# -1.1978461826541693
# {'c2st': 0.967820813771518, 'ml_efficacy': 0.4428901238835216, 'pair': 0.8640845348475943, 'shape': 0.8586923376945715}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 128, 'generator_decay': 5.6e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0004, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.689731076776396
# {'c2st': 0.9047013562858633, 'ml_efficacy': 0.8479046490438544, 'pair': 0.8705571425972795, 'shape': 0.8759706414211254}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00135, 'embedding_dim': 32, 'generator_decay': 4.6e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# Score:
# -1.3189599947509745
# {'c2st': 0.9405972874282734, 'ml_efficacy': 0.5402903180608098, 'pair': 0.8489086098062489, 'shape': 0.870358354312189}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00205, 'embedding_dim': 32, 'generator_decay': 1.4e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0021000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# Score:
# -1.344036674431818
# {'c2st': 0.9586593635889411, 'ml_efficacy': 0.6079939902272792, 'pair': 0.8406161940426969, 'shape': 0.8540858537507829}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0014500000000000001, 'embedding_dim': 32, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0047, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.5201964837368762
# {'c2st': 0.9064945226917058, 'ml_efficacy': 0.6730938387106579, 'pair': 0.8687740401546625, 'shape': 0.8848231275632618}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00185, 'embedding_dim': 128, 'generator_decay': 4.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00185, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.6402371283484354
# {'c2st': 0.8701747522170059, 'ml_efficacy': 0.7190824009487198, 'pair': 0.8837457710278008, 'shape': 0.9075837085889208}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 500, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00075, 'embedding_dim': 32, 'generator_decay': 6.3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0011, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# Score:
# -1.4704185305015989
# {'c2st': 0.9335224308815858, 'ml_efficacy': 0.7195468973532595, 'pair': 0.8737592615857408, 'shape': 0.8106348024441844}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 1000, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0018000000000000002, 'embedding_dim': 128, 'generator_decay': 6.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0022, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# Score:
# -1.370522084556381
# {'c2st': 0.9623109024517476, 'ml_efficacy': 0.6381035538187587, 'pair': 0.8470051958150951, 'shape': 0.8477242373742747}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0019500000000000001, 'embedding_dim': 128, 'generator_decay': 2.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0047, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.379222748926812
# {'c2st': 0.9627673448095982, 'ml_efficacy': 0.6383190699874218, 'pair': 0.8698034682879854, 'shape': 0.833867555461003}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0019, 'embedding_dim': 128, 'generator_decay': 4.2999999999999995e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0017000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.1360081241001412
# {'c2st': 0.9693531559728744, 'ml_efficacy': 0.44712186070534293, 'pair': 0.8468298766476309, 'shape': 0.8114095427200416}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0018000000000000002, 'embedding_dim': 32, 'generator_decay': 2.4999999999999998e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00095, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# Score:
# -1.1325816869347456
# {'c2st': 0.9523669796557122, 'ml_efficacy': 0.42939136005760586, 'pair': 0.834321976957984, 'shape': 0.821235329574868}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 500, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00095, 'embedding_dim': 32, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00125, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# Score:
# -1.308395385358852
# {'c2st': 0.9306207616066771, 'ml_efficacy': 0.5391969408438003, 'pair': 0.8601307569023784, 'shape': 0.8396884492193504}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 1000, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.002, 'embedding_dim': 32, 'generator_decay': 5.0999999999999995e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0032, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.2363542244307957
# {'c2st': 0.9577790818988002, 'ml_efficacy': 0.4879476628131833, 'pair': 0.8428389546298876, 'shape': 0.8633466888865251}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0009000000000000001, 'embedding_dim': 128, 'generator_decay': 3.6e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.004200000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# Score:
# -1.3476998353497565
# {'c2st': 0.9328377673448096, 'ml_efficacy': 0.5720086612768981, 'pair': 0.8544903639613688, 'shape': 0.8540385774562992}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.001, 'embedding_dim': 128, 'generator_decay': 4.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0006000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.727923636381064
# {'c2st': 0.8415818988002086, 'ml_efficacy': 0.7847168770442364, 'pair': 0.8863535034844577, 'shape': 0.8984351546525783}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 1000, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0019500000000000001, 'embedding_dim': 128, 'generator_decay': 2.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0012000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.4000421546617
# {'c2st': 0.9814814814814815, 'ml_efficacy': 0.7082630148741419, 'pair': 0.8520725679886555, 'shape': 0.8211880532803839}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00055, 'embedding_dim': 128, 'generator_decay': 5.6e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.8323085445897325
# {'c2st': 0.8656755346896192, 'ml_efficacy': 0.8906009395842474, 'pair': 0.8902868497023141, 'shape': 0.9170962899927902}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0004, 'embedding_dim': 128, 'generator_decay': 5.5e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.674780179552022
# {'c2st': 0.8820422535211269, 'ml_efficacy': 0.7610029117769056, 'pair': 0.8753104737953864, 'shape': 0.9205090475008569}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 128, 'generator_decay': 5.7999999999999995e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.6705166772131144
# {'c2st': 0.8828247261345853, 'ml_efficacy': 0.7584713300698566, 'pair': 0.8754891563541115, 'shape': 0.9193809169237316}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0011, 'embedding_dim': 128, 'generator_decay': 5.0999999999999995e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00265, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.7196461716702558
# {'c2st': 0.8939749608763693, 'ml_efficacy': 0.850437637868577, 'pair': 0.8850936933566755, 'shape': 0.8780898013213726}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00075, 'embedding_dim': 128, 'generator_decay': 3.1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0017000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.8364264585832584
# {'c2st': 0.8524713093375066, 'ml_efficacy': 0.9005660948447923, 'pair': 0.8845442509341203, 'shape': 0.9037874221418525}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00075, 'embedding_dim': 128, 'generator_decay': 3.1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0015, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.5754558144180775
# {'c2st': 0.8863458528951487, 'ml_efficacy': 0.6769830231303962, 'pair': 0.8800378289031315, 'shape': 0.9047808152796984}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0006500000000000001, 'embedding_dim': 128, 'generator_decay': 3.2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0022500000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.6243409974512284
# {'c2st': 0.8903560250391237, 'ml_efficacy': 0.7343388886004621, 'pair': 0.8858599126604698, 'shape': 0.8944982212294201}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0004, 'embedding_dim': 128, 'generator_decay': 3.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00255, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.6621583097798087
# {'c2st': 0.889280125195618, 'ml_efficacy': 0.8189446283964901, 'pair': 0.8747936801148487, 'shape': 0.8577001264640879}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 128, 'generator_decay': 2.8999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0037, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.760073599390848
# {'c2st': 0.8550469483568076, 'ml_efficacy': 0.8123158517818249, 'pair': 0.8903101622873807, 'shape': 0.9124945336784501}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00115, 'embedding_dim': 128, 'generator_decay': 4.2999999999999995e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.816713881254191
# {'c2st': 0.8887258737610851, 'ml_efficacy': 0.924078651062039, 'pair': 0.8834631261967338, 'shape': 0.8978979777565034}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00055, 'embedding_dim': 128, 'generator_decay': 3.6999999999999997e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0015500000000000002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.7202639774758284
# {'c2st': 0.8802164840897234, 'ml_efficacy': 0.8107449042272928, 'pair': 0.88299100297643, 'shape': 0.9067445543618291}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00075, 'embedding_dim': 128, 'generator_decay': 2.8e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0009000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.8192480329285234
# {'c2st': 0.846244131455399, 'ml_efficacy': 0.8889378363757245, 'pair': 0.8876595295824984, 'shape': 0.8888947984256995}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00045000000000000004, 'embedding_dim': 128, 'generator_decay': 1.6e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.742131020154754
# {'c2st': 0.9046361502347416, 'ml_efficacy': 0.8696671366094559, 'pair': 0.8859584294589863, 'shape': 0.8911416043210534}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'generator_decay': 3.5e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0019, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.6566877818085277
# {'c2st': 0.8716744913928013, 'ml_efficacy': 0.7459364809472263, 'pair': 0.8835781519321512, 'shape': 0.8988476403219515}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0012000000000000001, 'embedding_dim': 128, 'generator_decay': 1.1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00075, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.617242039535892
# {'c2st': 0.9021583202921232, 'ml_efficacy': 0.7633591593527692, 'pair': 0.8784105701640498, 'shape': 0.8776306303111961}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0014500000000000001, 'embedding_dim': 128, 'generator_decay': 5.3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0028, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.7998650452423033
# {'c2st': 0.8437010954616588, 'ml_efficacy': 0.8568363495136951, 'pair': 0.8836473767899077, 'shape': 0.9030824144003594}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 1000, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0007, 'embedding_dim': 128, 'generator_decay': 4.5e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00365, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.5742017070551237
# {'c2st': 0.9543883672404799, 'ml_efficacy': 0.8168093318916628, 'pair': 0.8772270897192382, 'shape': 0.8345536526847027}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 32, 'generator_decay': 6e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0041, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.7248813062457384
# {'c2st': 0.8698813249869589, 'ml_efficacy': 0.8196495293928941, 'pair': 0.8979800545280515, 'shape': 0.8771330473117517}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00125, 'embedding_dim': 128, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0014, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# Score:
# -1.6122832642927913
# {'c2st': 0.8886932707355242, 'ml_efficacy': 0.7531393413094033, 'pair': 0.8849378567689424, 'shape': 0.8628993369499699}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 1000, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00055, 'embedding_dim': 32, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.7664636827297162
# {'c2st': 0.8936489306207616, 'ml_efficacy': 0.9124503741861397, 'pair': 0.8788551382649065, 'shape': 0.8688071008994315}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0015500000000000002, 'embedding_dim': 128, 'generator_decay': 3.2999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00235, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# Score:
# -1.5150083626497617
# {'c2st': 0.8863458528951487, 'ml_efficacy': 0.6330328710435059, 'pair': 0.8898143298812103, 'shape': 0.8785070146201942}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 128, 'generator_decay': 6.3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0031000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.6153681878601827
# {'c2st': 0.8603286384976526, 'ml_efficacy': 0.6815556262287542, 'pair': 0.8796663806654307, 'shape': 0.9144748194636504}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 32, 'generator_decay': 2.8e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.3380868159626678
# {'c2st': 0.9198943661971831, 'ml_efficacy': 0.549796917091815, 'pair': 0.8594772717221741, 'shape': 0.8487069933458616}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00135, 'embedding_dim': 128, 'generator_decay': 4.7e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0029000000000000002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# Score:
# -1.6557649968554078
# {'c2st': 0.859122326551904, 'ml_efficacy': 0.7424173775043154, 'pair': 0.8799135984695082, 'shape': 0.8925563474334882}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 500, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0006500000000000001, 'embedding_dim': 128, 'generator_decay': 1.6e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0034500000000000004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.3635504314569298
# {'c2st': 0.9600286906624934, 'ml_efficacy': 0.6375317266660141, 'pair': 0.8552640272538085, 'shape': 0.8307833681996005}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.001, 'embedding_dim': 32, 'generator_decay': 2.2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0017000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.778112251851959
# {'c2st': 0.8603286384976526, 'ml_efficacy': 0.8941803635777889, 'pair': 0.8742130140958663, 'shape': 0.8700475126759565}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00045000000000000004, 'embedding_dim': 128, 'generator_decay': 3.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# Score:
# -1.5391374492563543
# {'c2st': 0.9036254564423577, 'ml_efficacy': 0.7167467132997379, 'pair': 0.8670183316512995, 'shape': 0.8589978607476746}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 1000, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00165, 'embedding_dim': 32, 'generator_decay': 4.2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.1991666956325786
# {'c2st': 0.9576160667709964, 'ml_efficacy': 0.4589035985115129, 'pair': 0.8431468068142097, 'shape': 0.8547323570778523}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008, 'embedding_dim': 128, 'generator_decay': 2.5999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# Score:
# -1.812468792908112
# {'c2st': 0.8774778299426186, 'ml_efficacy': 0.8855942163302037, 'pair': 0.8876561921698077, 'shape': 0.9166962143507192}
# --------------------------------------------------
# --------------------------------------------------
# {'batch_size': 500, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00095, 'embedding_dim': 128, 'generator_decay': 4.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0013000000000000002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Score:
# -1.4726957840326071
# {'c2st': 0.9336202399582681, 'ml_efficacy': 0.7128474074167035, 'pair': 0.877246347075655, 'shape': 0.8162222694985167}
# --------------------------------------------------
# 100%|██████████| 50/50 [1:06:25<00:00, 79.71s/trial, best loss: -1.8364264585832584]

# %%
print('Лучшие параметры:', results['best_hyperparameters'])
print('Лучший score:', results['best_score'])
print(results['best_com_score'])
# Out:
# Лучшие параметры: {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00075, 'embedding_dim': 128, 'generator_decay': 3.1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0017000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# Лучший score: -1.8364264585832584
# {'c2st': 0.8524713093375066, 'ml_efficacy': 0.9005660948447923, 'pair': 0.8845442509341203, 'shape': 0.9037874221418525}
